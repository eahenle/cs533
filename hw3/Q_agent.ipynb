# %% [markdown]
# ## Q-Learner

# %% [markdown]
# ### map_DH
#
# episodes = 60,000
#
# interval = 200
#
# #### Test 1
#
# epsilon = 0.1
#
# alpha = 0.1

# %% [markdown]
# ![test1_performance.png](attachment:18af21f1-a930-4695-942d-9add9fb7b749.png)
# ![test1_policy.png](attachment:708d134c-c9dd-45fc-8452-6931da1cd7b7.png)

# %% [markdown]
# #### Test 2
#
# epsilon = 0.1
#
# alpha = 0.001

# %% [markdown]
# ![test2_performance.png](attachment:247970d2-7ce4-42df-85fb-48dcf9352867.png)
# ![test2_policy.png](attachment:5a5466b1-5a1c-40f9-afc3-806f341a1b30.png)

# %% [markdown]
# #### Conclusion, Tests 1 & 2
#
# w/ epsilon = 0.1, better learning rate is 0.1
#
# #### Test 3
#
# epsilon = 0.3
#
# alpha = 0.1

# %% [markdown]
# ![test3_performance.png](attachment:0ebad616-a54e-48b8-8037-2e026b257fd6.png)
# ![test3_policy.png](attachment:e4b2c565-b236-4047-97bb-d92aca8b7af6.png)

# %% [markdown]
# #### Test 4
#
# epsilon = 0.005
#
# alpha = 0.1

# %% [markdown]
# ![test4_performance.png](attachment:cae81ba8-06f7-4194-9feb-46c6030ff5aa.png)
# ![test4_policy.png](attachment:0eb3d039-3ffc-456e-8c03-808dadf82f48.png)

# %% [markdown]
# #### Conclusion, Tests 3 & 4
#
# w/ alpha = 0.1, the best epsilon is 0.1 (but 0.05 is better than 0.3)
#
# ### map_16
#
# episodes = 200,000
#
# interval = 1,000
#
# #### Test 1
#
# epsilon = 0.1
#
# alpha = 0.1

# %% [markdown]
# ![test1_performance.png](attachment:56f1c4ee-9383-4934-abbf-98a48e077978.png)
# ![test1_policy.png](attachment:8724e088-b35e-42b0-b76c-a8af378daf3e.png)

# %% [markdown]
# #### Test 2
#
# epsilon = 0.1
#
# alpha = 0.001

# %% [markdown]
# ![test2_performance.png](attachment:19c1bac0-441f-45a0-9504-cd1a54300ed6.png)
# ![test2_policy.png](attachment:8f8b33c0-9a69-4583-8dfe-2ee250fb201d.png)

# %% [markdown]
# #### Conclusion, Tests 1 & 2
#
# w/ epsilon = 0.1, better learning rate is 0.1
#
# #### Test 3
#
# epsilon = 0.3
#
# alpha = 0.1

# %% [markdown]
# ![test3_performance.png](attachment:d545e3b5-0522-46e9-ae6c-0a8c3c550fba.png)
# ![test3_policy.png](attachment:4f1e0c4f-210f-4670-883b-e5f239e795cd.png)

# %% [markdown]
# #### Test 4
#
# epsilon = 0.05
#
# alpha = 0.1

# %% [markdown]
# ![test4_performance.png](attachment:756e702b-7156-4638-a532-2aeff874f6e6.png)
# ![test4_policy.png](attachment:14ed2084-079a-417f-b599-61bf45bc9553.png)

# %% [markdown]
# #### Conclusion, Tests 3 & 4
#
# w/ alpha = 0.1, the best epsilon is 0.1 (but 0.05 is better than 0.3)
