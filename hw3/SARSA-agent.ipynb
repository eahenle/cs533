# %% [markdown]
# ## SARSA-Learner

# %% [markdown]
# ### map_DH
#
# episodes = 60,000
#
# interval = 200
#
# #### Test 1
#
# epsilon = 0.1
#
# alpha = 0.1

# %% [markdown]
# ![test1_performance.png](attachment:46df4de6-5c7d-4637-82d5-744ffc7ecb28.png)
# ![test1_policy.png](attachment:d6b7c83f-74ad-4771-a183-867b9fe6904f.png)

# %% [markdown]
# #### Test 2
#
# epsilon = 0.1
#
# alpha = 0.001

# %% [markdown]
# ![test2_performance.png](attachment:3ac2ea0a-d26f-40d3-8cc1-207e853192e5.png)
# ![test2_policy.png](attachment:27fae9bc-709e-4817-b70a-10ceec618597.png)

# %% [markdown]
# #### Conclusion, Tests 1 & 2
#
# w/ epsilon = 0.1, better learning rate is 0.1
#
# #### Test 3
#
# epsilon = 0.3
#
# alpha = 0.1

# %% [markdown]
# ![test3_performance.png](attachment:c7e71d46-86ad-4b4c-b979-3a003d039b8f.png)
# ![test3_policy.png](attachment:1cb41be9-1535-4171-a9c0-754427d524e9.png)

# %% [markdown]
# #### Test 4
#
# epsilon = 0.005
#
# alpha = 0.1

# %% [markdown]
# ![test4_performance.png](attachment:5f71e2a3-840b-4760-8e85-8c92a29fe71d.png)
# ![test4_policy.png](attachment:86046648-3737-4ac7-b56a-baa6a23d591d.png)

# %% [markdown]
# #### Conclusion, Tests 3 & 4
#
# w/ alpha = 0.1, the best epsilon is 0.3
#
# ### map_16
#
# episodes = 200,000
#
# interval = 1000
#
# #### Test 1
#
# epsilon = 0.1
#
# alpha = 0.1

# %% [markdown]
# ![test1_performance.png](attachment:db97403a-af10-4a57-89fb-fbf13035be7e.png)
# ![test1_policy.png](attachment:eed53ca1-eaa5-4728-8ff3-5db6cbd2ff8a.png)

# %% [markdown]
# #### Test 2
#
# epsilon = 0.1
#
# alpha = 0.001

# %% [markdown]
# ![test2_performance.png](attachment:a3a447af-113b-42cb-823a-c86890ac34a8.png)
# ![test2_policy.png](attachment:6ee48ce3-0a96-46ca-9040-2fc89dd0ea23.png)

# %% [markdown]
# #### Conclusion, Tests 1 & 2
#
# w/ epsilon = 0.1, better learning rate is 0.1
#
# #### Test 3
#
# epsilon = 0.3
#
# alpha = 0.1

# %% [markdown]
# ![test3_performance.png](attachment:1c65b034-2ebb-4d48-a1c2-17605c49dcab.png)
# ![test3_policy.png](attachment:cf33fc3e-c876-4e7d-a837-4f4055a57a3d.png)

# %% [markdown]
# #### Test 4
#
# epsilon = 0.05
#
# alpha = 0.1

# %% [markdown]
# ![test4_performance.png](attachment:4812c2a1-107c-4464-b49e-c274a8fbbb32.png)
# ![test4_policy.png](attachment:3ab2ba65-b8e2-48d3-a9ff-b59306aa7510.png)

# %% [markdown]
# #### Conclusion, Tests 3 & 4
#
# w/ alpha = 0.1, the best epsilon is 0.005
